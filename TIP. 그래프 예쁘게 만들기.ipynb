# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('event_log.csv')

# %%
df['event_date'] = df['event_time'].str.slice(start=0, stop=10)
df['event_date_dtm_format'] = pd.to_datetime(df['event_date'], format='%Y-%m-%d')

# %%
df2 = df.groupby('event_date')['user_id'].nunique()
dau_data = pd.DataFrame({'event_date': df2.index, 'user_count':df2.values})

# %%
dau_data
# Out:
#      event_date  user_count
# 0    2020-09-24        1358
# 1    2020-09-25        2451
# 2    2020-09-26        2030
# 3    2020-09-27        2187
# 4    2020-09-28        2732
# ..          ...         ...
# 153  2021-02-24        2904
# 154  2021-02-25        2784
# 155  2021-02-26        2960
# 156  2021-02-27        2578
# 157  2021-02-28        2775
#
# [158 rows x 2 columns]

# %%
sns.lineplot(x='event_date', y='user_count', data=dau_data)
# Out:
# <AxesSubplot:xlabel='event_date', ylabel='user_count'>

# %% [markdown]
# 테마 및 색상 팔레트 변경<br>
# 테마 종류: https://seaborn.pydata.org/generated/seaborn.set_theme.html<br>
# 색상 팔레트 종류: https://seaborn.pydata.org/tutorial/color_palettes.html#palette-tutorial

# %%
sns.set_theme(style="whitegrid", palette='pastel')

# %%
sns.lineplot(x='event_date', y='user_count', data=dau_data)
# Out:
# <AxesSubplot:xlabel='event_date', ylabel='user_count'>

# %%
g = sns.lineplot(x='event_date', y='user_count', data=dau_data)
g.figure.set_size_inches(15, 8)

# %%
import matplotlib.ticker as ticker

# %%
g = sns.lineplot(x='event_date', y='user_count', data=dau_data)
g.figure.set_size_inches(15, 8)
g.xaxis.set_major_locator(ticker.MultipleLocator(7))

# %%
plt.xticks(rotation=45)
g = sns.lineplot(x='event_date', y='user_count', data=dau_data)
g.figure.set_size_inches(15, 8)
g.xaxis.set_major_locator(ticker.MultipleLocator(7))

# %%
plt.xticks(rotation=45)
plt.rc('font', family='NanumGothic')

g = sns.lineplot(x='event_date', y='user_count', data=dau_data)
g.figure.set_size_inches(15, 8)
g.xaxis.set_major_locator(ticker.MultipleLocator(7))
g.set_title('일자별 DAU 변화(Daily Active User)', pad=20, size=20)
g.set_xlabel('일자', labelpad=10, size=13)
g.set_ylabel('유저수', labelpad=20, size=13)
# Out:
# Text(0, 0.5, '유저수')
